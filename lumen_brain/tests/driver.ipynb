# %%
from lumen_brain.async_driver import AsyncLumenBrainDriver
from lumen_brain.sync_driver import LumenBrainDriver

import os
from dotenv import load_dotenv
load_dotenv()

key = os.getenv("TEST_APY_KEY")

client = LumenBrainDriver(api_key=key)
aclient = AsyncLumenBrainDriver(api_key=key)

# client.save_message(
#     memory_uuid="your-memory-uuid",
#     type="message",
#     content="Your message content",
#     role="user",
# )

# client.inject_knowledge(
#     memory_uuid="unique_user_001",
#     type="email",
#     content=mock_email,
#     metadata={}
# )

# result = client.fetch_info(
#     memory_uuid="unique_user_identifier_123",
#     entities=["john"],
#     info="wedding date",
#     depth=2
# )
result = await aclient.fetch_info(
    memory_uuid="unique_user_identifier_123",
    entities=["john"],
    info="wedding date",
    depth=2
)
result.most_relevant_relation.related_node.name
# Out:
# {'most_relevant_relation': {'direction': 'outbound',
#                             'name': 'HAS_DATE',
#                             'natural_lang': "Mary's wedding is in October 22th",
#                             'phrase': "Mary's wedding is in October 22th",
#                             'related_node': {'id': '689c8b6167197b56ebf68855',
#                                              'name': 'October 22th',
#                                              'natural_lang': 'Date: October '
#                                                              '22th, October '
#                                                              '22th',
#                                              'parent_id': None,
#                                              'relationships': [],
#                                              'source_id': '689c8b6167197b56ebf68855'},
#                             'similarity': 0.7179440259933472,
#                             'source_id': '689c8b6167197b56ebf68856'},
#  'nodes': [{'id': '689c652667197b56ebf68831',
#             'name': 'John',
#             'natural_lang': "Person: John, the name of Mary's husband",
#             'parent_id': None,
#             'relationships': [{'direction': 'outbound',
#                                'name': 'IS_GROOM_OF',
#                                'natural_lang': "John is the groom at Mary's "
#                                                'wedding',
#                                'phrase': "John is the groom at Mary's wedding",
#                                'related_node': {'id': '689c8ac367197b56ebf68838',
#                                                 'name': 'Wedding',
#                                                 'natural_lang': 'Event: '
#                                                                 'Wedding, '
#                                                                 "Mary's "
#                                                                 'wedding on '
#                                                                 'October 22th',
#                                                 'parent_id': None,
#                                                 'relationships': [{'direction': 'outbound',
#                                                                    'name': 'HAS_DATE',
#                                                                    'natural_lang': "Mary's "
#                                                                                    'wedding '
#                                                                                    'is '
#                                                                                    'in '
#                                                                                    'October '
#                                                                                    '22th',
#                                                                    'phrase': "Mary's "
#                                                                              'wedding '
#                                                                              'is '
#                                                                              'in '
#                                                                              'October '
#                                                                              '22th',
#                                                                    'related_node': {'id': '689c8b6167197b56ebf68855',
#                                                                                     'name': 'October '
#                                                                                             '22th',
#                                                                                     'natural_lang': 'Date: '
#                                                                                                     'October '
#                                                                                                     '22th, '
#                                                                                                     'October '
#                                                                                                     '22th',
#                                                                                     'parent_id': 'None',
#                                                                                     'relationships': '[]',
#                                                                                     'source_id': '689c8b6167197b56ebf68855'},
#                                                                    'similarity': 0.7179440259933472,
#                                                                    'source_id': '689c8b6167197b56ebf68856'},
#                                                                   {'direction': 'outbound',
#                                                                    'name': 'HAS_LOCATION',
#                                                                    'natural_lang': "Mary's "
#                                                                                    'wedding '
#                                                                                    'will '
#                                                                                    'be '
#                                                                                    'in '
#                                                                                    'New '
#                                                                                    'York',
#                                                                    'phrase': "Mary's "
#                                                                              'wedding '
#                                                                              'will '
#                                                                              'be '
#                                                                              'in '
#                                                                              'New '
#                                                                              'York',
#                                                                    'related_node': {'id': '689c8b6067197b56ebf6884f',
#                                                                                     'name': 'New '
#                                                                                             'York',
#                                                                                     'natural_lang': 'Location: '
#                                                                                                     'New '
#                                                                                                     'York, '
#                                                                                                     'New '
#                                                                                                     'York',
#                                                                                     'parent_id': 'None',
#                                                                                     'relationships': '[]',
#                                                                                     'source_id': '689c8b6067197b56ebf6884f'},
#                                                                    'similarity': 0.6844737529754639,
#                                                                    'source_id': '689c8b6067197b56ebf68853'},
#                                                                   {'direction': 'inbound',
#                                                                    'name': 'WILL_NOT_ATTEND',
#                                                                    'natural_lang': 'julia '
#                                                                                    'will '
#                                                                                    'not '
#                                                                                    'be '
#                                                                                    'present '
#                                                                                    'at '
#                                                                                    'the '
#                                                                                    'wedding',
#                                                                    'phrase': 'julia '
#                                                                              'will '
#                                                                              'not '
#                                                                              'be '
#                                                                              'present '
#                                                                              'at '
#                                                                              'the '
#                                                                              'wedding',
#                                                                    'related_node': {'id': '689de3a2d3f7c1f017aaf0b9',
#                                                                                     'name': 'Julia',
#                                                                                     'natural_lang': 'Person: '
#                                                                                                     'Julia, '
#                                                                                                     'Julia, '
#                                                                                                     'a '
#                                                                                                     'level '
#                                                                                                     '3 '
#                                                                                                     'manager '
#                                                                                                     'at '
#                                                                                                     'Oracle',
#                                                                                     'parent_id': 'None',
#                                                                                     'relationships': '[]',
#                                                                                     'source_id': '689de3a2d3f7c1f017aaf0b9'},
#                                                                    'similarity': 0.6210842132568359,
#                                                                    'source_id': '689de3d0d3f7c1f017aaf0c2'},
#                                                                   {'direction': 'inbound',
#                                                                    'name': 'SHARES_LOCATION_WITH',
#                                                                    'natural_lang': 'Anime '
#                                                                                    'Fair '
#                                                                                    'and '
#                                                                                    "Mary's "
#                                                                                    'wedding '
#                                                                                    'are '
#                                                                                    'both '
#                                                                                    'in '
#                                                                                    'New '
#                                                                                    'York',
#                                                                    'phrase': 'Anime '
#                                                                              'Fair '
#                                                                              'and '
#                                                                              "Mary's "
#                                                                              'wedding '
#                                                                              'are '
#                                                                              'both '
#                                                                              'in '
#                                                                              'New '
#                                                                              'York',
#                                                                    'related_node': {'id': '689de5a4d3f7c1f017aaf11f',
#                                                                                     'name': 'Anime '
#                                                                                             'Fair',
#                                                                                     'natural_lang': 'Event: '
#                                                                                                     'Anime '
#                                                                                                     'Fair, '
#                                                                                                     'one '
#                                                                                                     'of '
#                                                                                                     'the '
#                                                                                                     'biggest '
#                                                                                                     'fairs '
#                                                                                                     'of '
#                                                                                                     'anime',
#                                                                                     'parent_id': 'None',
#                                                                                     'relationships': '[]',
#                                                                                     'source_id': '689de5a4d3f7c1f017aaf11f'},
#                                                                    'similarity': 0.6171935796737671,
#                                                                    'source_id': '689de5a4d3f7c1f017aaf11b'}],
#                                                 'source_id': '689c8ac367197b56ebf68838'},
#                                'similarity': 0.5091792941093445,
#                                'source_id': '689c8ac367197b56ebf6883c'},
#                               {'direction': 'inbound',
#                                'name': 'IS_NAMED',
#                                'natural_lang': "Mary's husband is named John",
#                                'phrase': "Mary's husband is named John",
#                                'related_node': {'id': '689c652667197b56ebf68830',
#                                                 'name': 'Mary',
#                                                 'natural_lang': 'Person: Mary, '
#                                                                 "Mary's "
#                                                                 'husband',
#                                                 'parent_id': None,
#                                                 'relationships': [],
#                                                 'source_id': '689c652667197b56ebf68830'},
#                                'similarity': 0.3461538255214691,
#                                'source_id': '689c652667197b56ebf68832'},
#                               {'direction': 'outbound',
#                                'name': 'IS_MARRIED_TO',
#                                'natural_lang': "John is Mary's husband",
#                                'phrase': "John is Mary's husband",
#                                'related_node': {'id': '689c652667197b56ebf68830',
#                                                 'name': 'Mary',
#                                                 'natural_lang': 'Person: Mary, '
#                                                                 "Mary's "
#                                                                 'husband',
#                                                 'parent_id': None,
#                                                 'relationships': [],
#                                                 'source_id': '689c652667197b56ebf68830'},
#                                'similarity': 0.3339197337627411,
#                                'source_id': '689c8b1e67197b56ebf68846'},
#                               {'direction': 'inbound',
#                                'name': 'IS_PROUD_OF',
#                                'natural_lang': 'Mary is really proud of John',
#                                'phrase': 'Mary is really proud of John',
#                                'related_node': {'id': '689c652667197b56ebf68830',
#                                                 'name': 'Mary',
#                                                 'natural_lang': 'Person: Mary, '
#                                                                 "Mary's "
#                                                                 'husband',
#                                                 'parent_id': None,
#                                                 'relationships': [],
#                                                 'source_id': '689c652667197b56ebf68830'},
#                                'similarity': 0.32522594928741455,
#                                'source_id': '689c8b1e67197b56ebf68843'},
#                               {'direction': 'outbound',
#                                'name': 'WILL_BE_DISPATCHED_TO',
#                                'natural_lang': 'Navy Seal John will probably '
#                                                'need to be dispatched in '
#                                                'October in the Middle East',
#                                'phrase': 'Navy Seal John will probably need to '
#                                          'be dispatched in October in the '
#                                          'Middle East',
#                                'related_node': {'id': '689de4aed3f7c1f017aaf0ea',
#                                                 'name': 'Middle East in '
#                                                         'October',
#                                                 'natural_lang': 'LocationTime: '
#                                                                 'Middle East '
#                                                                 'in October, '
#                                                                 'in October in '
#                                                                 'the Middle '
#                                                                 'East',
#                                                 'parent_id': None,
#                                                 'relationships': [],
#                                                 'source_id': '689de4aed3f7c1f017aaf0ea'},
#                                'similarity': 0.28959017992019653,
#                                'source_id': '689de4aed3f7c1f017aaf0eb'},
#                               {'direction': 'outbound',
#                                'name': 'WILL_OPERATE_IN',
#                                'natural_lang': 'John will have to operate in '
#                                                'the Middle East in October',
#                                'phrase': 'John will have to operate in the '
#                                          'Middle East in October',
#                                'related_node': {'id': '689de42fd3f7c1f017aaf0d1',
#                                                 'name': 'Middle East',
#                                                 'natural_lang': 'Location: '
#                                                                 'Middle East, '
#                                                                 'the Middle '
#                                                                 'East region',
#                                                 'parent_id': None,
#                                                 'relationships': [],
#                                                 'source_id': '689de42fd3f7c1f017aaf0d1'},
#                                'similarity': 0.2594348192214966,
#                                'source_id': '689de42fd3f7c1f017aaf0d2'},
#                               {'direction': 'outbound',
#                                'name': 'HAS_JOB',
#                                'natural_lang': 'John is a Navy Seal',
#                                'phrase': 'John is a Navy Seal',
#                                'related_node': {'id': '689c8b1e67197b56ebf68848',
#                                                 'name': 'Navy Seal',
#                                                 'natural_lang': 'Job: Navy '
#                                                                 'Seal, a Navy '
#                                                                 'Seal',
#                                                 'parent_id': None,
#                                                 'relationships': [],
#                                                 'source_id': '689c8b1e67197b56ebf68848'},
#                                'similarity': 0.2549767792224884,
#                                'source_id': '689c8b1e67197b56ebf68849'}],
#             'source_id': '689c652667197b56ebf68831'}]}
# 'October 22th'
